# %%
#ex 1 a
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
syst
# Out:
# [diff(x(t), t) == x(t) + 4*y(t), diff(y(t), t) == x(t) + y(t)]

# %%
desolve_system(syst,[x,y])
# Out:
# [x(t) == 1/2*(x(0) + 2*y(0))*e^(3*t) + 1/2*(x(0) - 2*y(0))*e^(-t),
#  y(t) == 1/4*(x(0) + 2*y(0))*e^(3*t) - 1/4*(x(0) - 2*y(0))*e^(-t)]

# %%
sol_syst=desolve_system(syst,[x,y])
show(sol_syst)
# Out:
# [x(t) == 1/2*(x(0) + 2*y(0))*e^(3*t) + 1/2*(x(0) - 2*y(0))*e^(-t),
#  y(t) == 1/4*(x(0) + 2*y(0))*e^(3*t) - 1/4*(x(0) - 2*y(0))*e^(-t)]

# %%
#ex 2 b
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==2*x-y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
syst
# Out:
# [diff(x(t), t) == 2*x(t) - y(t), diff(y(t), t) == x(t) + y(t)]

# %%
sol_syst=desolve_system(syst,[x,y])
show(sol_syst)
# Out:
# [x(t) == 1/3*(sqrt(3)*(x(0) - 2*y(0))*sin(1/2*sqrt(3)*t) + 3*cos(1/2*sqrt(3)*t)*x(0))*e^(3/2*t),
#  y(t) == 1/3*(sqrt(3)*(2*x(0) - y(0))*sin(1/2*sqrt(3)*t) + 3*cos(1/2*sqrt(3)*t)*y(0))*e^(3/2*t)]

# %%
#ex 1 c
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==x-y+z
deq2=diff(y,t)==x+y-z
deq3=diff(z,t)==-y+2*z
syst=[deq1,deq2,deq3]
syst
# Out:
# [diff(x(t), t) == x(t) - y(t) + z(t),
#  diff(y(t), t) == x(t) + y(t) - z(t),
#  diff(z(t), t) == -y(t) + 2*z(t)]

# %%
sol_syst=desolve_system(syst,[x,y,z])
show(sol_syst)
# Out:
# [x(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) + y(0) - 2*z(0))*e^(2*t) + (2*x(0) + y(0) - 2*z(0))*e^t,
#  y(t) == t*e^t*x(0) - t*e^t*z(0) + e^t*y(0),
#  z(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) + y(0) - 2*z(0))*e^(2*t) + (x(0) + y(0) - z(0))*e^t]

# %%
#ex 1 d
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==5*x+3*y+1
deq2=diff(y,t)==-6*x-4*y+e^(-t)
syst=[deq1,deq2]
syst
# Out:
# [diff(x(t), t) == 5*x(t) + 3*y(t) + 1,
#  diff(y(t), t) == e^(-t) - 6*x(t) - 4*y(t)]

# %%
sol_syst=desolve_system(syst,[x,y])
show(sol_syst)
# Out:
# [x(t) == 1/3*(6*x(0) + 3*y(0) + 4)*e^(2*t) - t*e^(-t) - 1/3*(3*x(0) + 3*y(0) - 2)*e^(-t) - 2,
#  y(t) == -1/3*(6*x(0) + 3*y(0) + 4)*e^(2*t) + 2*t*e^(-t) + 1/3*(6*x(0) + 6*y(0) - 5)*e^(-t) + 3]

# %%
#ex 1 e
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+3*t+cos(t)
deq2=diff(y,t)==x-y+2*t
syst=[deq1,deq2]
syst
# Out:
# [diff(x(t), t) == 3*t + cos(t) + x(t), diff(y(t), t) == 2*t + x(t) - y(t)]

# %%
sol_syst=desolve_system(syst,[x,y])
show(sol_syst)
# Out:
# [x(t) == 1/2*(2*x(0) + 7)*e^t - 3*t - 1/2*cos(t) + 1/2*sin(t) - 3,
#  y(t) == -1/4*(2*x(0) - 4*y(0) - 3)*e^(-t) + 1/4*(2*x(0) + 7)*e^t - t - 1/2*cos(t) - 2]

# %%
#ex 1 f
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==x-2*y-2*z+e^(-t)
deq2=diff(y,t)==x+y-z
deq3=diff(z,t)==-y+2*z
syst=[deq1,deq2,deq3]
syst
# Out:
# [diff(x(t), t) == e^(-t) + x(t) - 2*y(t) - 2*z(t),
#  diff(y(t), t) == x(t) + y(t) - z(t),
#  diff(z(t), t) == -y(t) + 2*z(t)]

# %%
sol_syst=desolve_system(syst,[x,y,z])
show(sol_syst)
# Out:
# [x(t) == -5/18*e^(-t) + ilt(1/18*(g2479^2*(18*x(0) + 5) - g2479*(54*x(0) + 36*y(0) + 36*z(0) + 7) + 18*x(0) + 108*y(0) + 72*z(0) - 17)/(g2479^3 - 4*g2479^2 + 6*g2479 - 7), g2479, t),
#  y(t) == 1/6*e^(-t) + ilt(1/6*(g2479^2*(6*y(0) - 1) + g2479*(6*x(0) - 18*y(0) - 6*z(0) + 5) - 12*x(0) + 12*y(0) - 6*z(0) - 5)/(g2479^3 - 4*g2479^2 + 6*g2479 - 7), g2479, t),
#  z(t) == 1/18*e^(-t) + ilt(1/18*(g2479^2*(18*z(0) - 1) - g2479*(18*y(0) + 36*z(0) - 5) - 18*x(0) + 18*y(0) + 54*z(0) - 11)/(g2479^3 - 4*g2479^2 + 6*g2479 - 7), g2479, t)]

# %%
#exercitiul 2 a
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
syst
# Out:
# [diff(x(t), t) == x(t) + 4*y(t), diff(y(t), t) == x(t) + y(t)]

# %%
sol_syst=desolve_system(syst,[x,y])
show(sol_syst)
# Out:
# [x(t) == 1/2*(x(0) + 2*y(0))*e^(3*t) + 1/2*(x(0) - 2*y(0))*e^(-t),
#  y(t) == 1/4*(x(0) + 2*y(0))*e^(3*t) - 1/4*(x(0) - 2*y(0))*e^(-t)]

# %%
C1,C2=var('C1,C2')
sol_syst=desolve_system(syst,[x,y],[0,C1,C2])
show(sol_syst)
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]

# %%
sol_x(t,C1,C2)=sol_syst[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t)

# %%
show(sol_x)
# Out:
# (t, C1, C2) |--> 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t)

# %%
sol_y(t,C1,C2)=sol_syst[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)

# %%
show(sol_y)
# Out:
# (t, C1, C2) |--> 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)

# %%
plot(sol_x(t,1,2),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t,1,2),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t,1,2),t,-4,4,color='red')
g2=plot(sol_y(t,1,2),t,-4,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#### 
# ex 2 a
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,1,2]

# %%
sol=desolve_system(syst,vars,in_cond)
sol
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]

# %%
show(sol)
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> 5/2*e^(3*t) - 3/2*e^(-t)

# %%
show(sol_x)
# Out:
# t |--> 5/2*e^(3*t) - 3/2*e^(-t)

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> 5/4*e^(3*t) + 3/4*e^(-t)

# %%
show(sol_y)
# Out:
# t |--> 5/4*e^(3*t) + 3/4*e^(-t)

# %%
plot(sol_x(t),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t),t,-4,4,color='red')
g2=plot(sol_y(t),t,-4,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#### 
# ex 2 b
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x-y+t-1
deq2=diff(y,t)==-2*x+4*y+cos(t)
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]

# %%
sol=desolve_system(syst,vars,in_cond)
sol
# Out:
# [x(t) == -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2,
#  y(t) == -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2]

# %%
show(sol)
# Out:
# [x(t) == -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2,
#  y(t) == -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2

# %%
show(sol_x)
# Out:
# t |--> -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2

# %%
show(sol_y)
# Out:
# t |--> -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2

# %%
plot(sol_x(t),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t),t,-10,10,color='red')
g2=plot(sol_y(t),t,-10,10,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#### 
# ex 2 c
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+2*y+e^(-t)
deq2=diff(y,t)==-2*x+y+1
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]

# %%
sol=desolve_system(syst,vars,in_cond)
sol
# Out:
# [x(t) == -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5,
#  y(t) == 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5]

# %%
show(sol)
# Out:
# [x(t) == -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5,
#  y(t) == 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5

# %%
show(sol_x)
# Out:
# t |--> -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5

# %%
show(sol_y)
# Out:
# t |--> 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5

# %%
plot(sol_x(t),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t),t,-4,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=plot(sol_x(t),t,-10,10,color='red')
g2=plot(sol_y(t),t,-10,10,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#### 
# ex 2 d
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==-x+3*y+3*z+27*t^2
deq2=diff(y,t)==2*x-2*y-5*z+3*t
deq3=diff(z,t)==-2*x+3*y+6*z+3
syst=[deq1,deq2,deq3]
vars=[x,y,z]
in_cond=[0,50,-30,26]

# %%
sol=desolve_system(syst,vars,in_cond)
sol
# Out:
# [x(t) == 27*t^2 - 63*t + 2*e^(-t) + 3*e^t + 45,
#  y(t) == -18*t^2 + 24*t + e^(3*t) - e^(-t) + 2*e^t - 32,
#  z(t) == 18*t^2 - 27*t - e^(3*t) + e^(-t) + 26]

# %%
show(sol)
# Out:
# [x(t) == 27*t^2 - 63*t + 2*e^(-t) + 3*e^t + 45,
#  y(t) == -18*t^2 + 24*t + e^(3*t) - e^(-t) + 2*e^t - 32,
#  z(t) == 18*t^2 - 27*t - e^(3*t) + e^(-t) + 26]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> 27*t^2 - 63*t + 2*e^(-t) + 3*e^t + 45

# %%
show(sol_x)
# Out:
# t |--> 27*t^2 - 63*t + 2*e^(-t) + 3*e^t + 45

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> -18*t^2 + 24*t + e^(3*t) - e^(-t) + 2*e^t - 32

# %%
show(sol_y)
# Out:
# t |--> -18*t^2 + 24*t + e^(3*t) - e^(-t) + 2*e^t - 32

# %%
sol_z(t)=sol[2].rhs()
sol_z
# Out:
# t |--> 18*t^2 - 27*t - e^(3*t) + e^(-t) + 26

# %%
show(sol_z)
# Out:
# t |--> 18*t^2 - 27*t - e^(3*t) + e^(-t) + 26

# %%
g1=plot(sol_x(t),t,-4,4,color='red')
g1
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g2=plot(sol_y(t),t,-4,4,color='blue')
g2
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g3=plot(sol_z(t),t,-4,4,color='yellow')
g3
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(g1+g2+g3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
# exercitiul 3 a
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+y
deq2=diff(y,t)==-2*x+4*y
syst=[deq1,deq2]
syst
vars=[x,y]
in_cond=[0,3,0]

# %%
sol_1=desolve_system(syst,vars,in_cond)
sol_1
# Out:
# [x(t) == -3*e^(3*t) + 6*e^(2*t), y(t) == -6*e^(3*t) + 6*e^(2*t)]

# %%
in_cond=[0,0,3]
sol_2=desolve_system(syst,vars,in_cond)
sol_2
# Out:
# [x(t) == 3*e^(3*t) - 3*e^(2*t), y(t) == 6*e^(3*t) - 3*e^(2*t)]

# %%
in_cond=[0,-3,0]
sol_3=desolve_system(syst,vars,in_cond)
sol_3
# Out:
# [x(t) == 3*e^(3*t) - 6*e^(2*t), y(t) == 6*e^(3*t) - 6*e^(2*t)]

# %%
in_cond=[0,0,-3]
sol_4=desolve_system(syst,vars,in_cond)
sol_4
# Out:
# [x(t) == -3*e^(3*t) + 3*e^(2*t), y(t) == -6*e^(3*t) + 3*e^(2*t)]

# %%
#3 b
limit(sol_1[0].rhs(),t=infinity)
# Out:
# -Infinity

# %%
limit(sol_1[1].rhs(),t=infinity)
# Out:
# -Infinity

# %%
limit(sol_2[0].rhs(),t=infinity)
# Out:
# +Infinity

# %%
limit(sol_2[1].rhs(),t=infinity)
# Out:
# +Infinity

# %%
limit(sol_3[0].rhs(),t=infinity)
# Out:
# +Infinity

# %%
limit(sol_3[1].rhs(),t=infinity)
# Out:
# +Infinity

# %%
limit(sol_4[0].rhs(),t=infinity)
# Out:
# -Infinity

# %%
limit(sol_4[1].rhs(),t=infinity)
# Out:
# -Infinity

# %%
# 3 c??????????howw?
u,v=var('u,v')
f1=function('u,v')()
f1(u,v)=u+v
f2(u,v)=-2*u+4*v
plot_vector_field([f1(u,v),f2(u,v)],[u,-10,10],[v,10,10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/all_cmdline.py in <module>
#       3 __tmp__=var("u,v"); f1 = symbolic_expression(u+v).function(u,v)
#       4 __tmp__=var("u,v"); f2 = symbolic_expression(-Integer(2)*u+Integer(4)*v).function(u,v)
# ----> 5 plot_vector_field([f1(u,v),f2(u,v)],[u,-Integer(10),Integer(10)],[v,Integer(10),Integer(10)])
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     489                 options['__original_opts'] = kwds
#     490             options.update(kwds)
# --> 491             return func(*args, **options)
#     492
#     493         #Add the options specified by @options to the signature of the wrapped
#
# ...
